# %% [markdown]
# # Metadata Scraping - Tracks
#
# Os dados fornecidos pelo Spotify são bastante secos em termos de catergorização das músicas presentes em cada uma das playlists. Em uma estratégia utilizando puramente técnicas de Filtro Colaborativo, que é nosso foco neste projeto, isso seria suficiente. Mas buscaremos observar também técnicas relacionadas sistemas Baseados em Conteúdo, bem como estratégias híbridas, bem como será interessante analisar alguns padrões nas diversas listagens disponíveis.
#
# Assim, no presente notebook, nos utilizamos do módulo [Spotipy](https://spotipy.readthedocs.io/en/latest/) para nos utilizar de dados do Spotify para enriquecer nossa base de dados.
#
# Dados de <b>FAIXAS</b>
#
# <br><br>
# <hr>
# @author: [Pedro Correia](https://github.com/pfcor)

# %%
import math
import pprint
from collections import defaultdict
import pandas as pd
import numpy as np
import tqdm
import time
import datetime as dt
import os

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# Vamos iterar faixa a faixa e obter informações relacionadas ao artista (estilos, popularidade, número de seguidores e artistas similares)e à música (níveis de ritmos, instrumentação, etc)

# %%
def spotipy_auth():
    
    # initializing and authenticating
    from spotipy_credencials import CLIENT_ID, CLIENT_SECRET
    ccm = SpotifyClientCredentials( client_id=CLIENT_ID, client_secret=CLIENT_SECRET )
    sp = spotipy.Spotify(client_credentials_manager=ccm)
    return sp


def get_tracks_uri(ntracks=None):
    
    return pd.read_csv("data/formatted/tracks.csv", nrows=ntracks, usecols=["track_uri"])["track_uri"].values


def get_top_n_related_artists(artist_uri, n=3, sort_by="popularity", include_name=False):
    
    assert sort_by in ["popularity", "similarity"]
    
    related_artists = [
        (rartist["uri"], rartist["name"], rartist["popularity"]) 
        for rartist 
        in sp.artist_related_artists(artist_uri)["artists"]
    ]
    
    if sort_by=="popularity":
        related_artists = sorted(related_artists, key=lambda x: -x[-1])[:n]
    
    return [rartist[:2] if include_name else rartist[0] for rartist in related_artists[:n]]

# %%
def scrape_track_metadata(batch_size=50, output_folder="data/metadata", start_batch=0):
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    filename = output_folder + '/tracks_metadata.csv'
    failed_index = []
    
    
    print("|Initializing Spotify API...", end=" ", flush=True)
    sp = spotipy_auth()
    print("ok\n")
    
    print("|Loading tracks...", end=" ", flush=True)
    tracks = get_tracks_uri()
    n_tracks = len(tracks)
    print("ok")
    
    print(f"    > {n_tracks} tracks to be processed\n")
    
    print("|Gathering Spotify data")
    t0 = time.time()
    

    batches_count = math.ceil(n_tracks / batch_size)
    print(f"    > {batches_count} batches to be processed")
    
    for i in range(start_batch, batches_count):
        spotify_data = defaultdict(list)
        
#         print(f'        - batch # {i+1:0>2}', end=" ", flush=True)
        try:
            i_0 = i * batch_size
            i_f = i_0 + batch_size           
            batch = tracks[i_0:i_f]

            # general data
            tracks_data = sp.tracks(batch)["tracks"]
            for track in tracks_data:
                if track != None:
                    spotify_data['track_uri'].append(track['uri'])
                    spotify_data['popularity'].append(track['popularity'])
                    spotify_data['realease_year'].append(int(track['album']['release_date'].split("-")[0]))
                else:
                    spotify_data['track_uri'].append(np.nan)
                    spotify_data['popularity'].append(np.nan)
                    spotify_data['realease_year'].append(np.nan)

            # audio data
            track_audio_features = sp.audio_features(batch)
            for track in track_audio_features:
                if track != None:
                    spotify_data['acousticness'].append(track['acousticness'])
                    spotify_data['danceability'].append(track['danceability'])
                    spotify_data['energy'].append(track['energy'])
                    spotify_data['instrumentalness'].append(track['instrumentalness'])
                    spotify_data['mode'].append(track['mode'])
                    spotify_data['loudness'].append(track['loudness'])
                    spotify_data['speechiness'].append(track['speechiness'])
                    spotify_data['tempo'].append(track['tempo'])
                    spotify_data['time_signature'].append(track['time_signature'])
                    spotify_data['valence'].append(track['valence'])

                else:
                    spotify_data['acousticness'].append(np.nan)
                    spotify_data['danceability'].append(np.nan)
                    spotify_data['energy'].append(np.nan)
                    spotify_data['instrumentalness'].append(np.nan)
                    spotify_data['mode'].append(np.nan)
                    spotify_data['loudness'].append(np.nan)
                    spotify_data['speechiness'].append(np.nan)
                    spotify_data['tempo'].append(np.nan)
                    spotify_data['time_signature'].append(np.nan)
                    spotify_data['valence'].append(np.nan)

            try:
                spotify_data = pd.DataFrame(spotify_data)
                spotify_data.to_csv(filename, sep=";", index=False, header=(i==0), mode="w" if (i==0) else "a")
            except:
                for feat, vals in spotify_data.items():
                    print(feat, len(vals))
                
            if ((i+1)%100 == 0) or ((i+1) == batches_count):
                print(f'        - {i+1:>8} batches completed | {batches_count-(i+1):>8} to go | elapsed time: {str(dt.timedelta(seconds=time.time()-t0))}')
        except TimeoutError:
            failed_index.append((i_0, i_f))
            sp = spotipy_auth()

# %%
scrape_track_metadata(start_batch=45200)
# Out:
# |Initializing Spotify API... ok
#
# |Loading tracks... ok
#     > 2262292 tracks to be processed
#
# |Gathering Spotify data
#     > 45246 batches to be processed
#         -    45246 batches completed |        0 to go | elapsed time: 0:00:34.580821

# %%
tracks_metadata = pd.read_csv("data/metadata/tracks_metadata.csv", sep=";")

# %%
tracks_metadata.shape
# Out:
# (2278792, 13)

# %%
tracks_metadata.head()
# Out:
#                               track_uri  popularity  realease_year  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI        63.0         2005.0
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak        77.0         2003.0
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv        58.0         2003.0
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT        71.0         2002.0
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H        27.0         2000.0
#
#    acousticness  danceability  energy  instrumentalness  mode  loudness  \
# 0       0.03110         0.904   0.813          0.006970   0.0    -7.105
# 1       0.02490         0.774   0.838          0.025000   0.0    -3.914
# 2       0.00238         0.664   0.758          0.000000   0.0    -6.583
# 3       0.20200         0.891   0.714          0.000234   0.0    -6.055
# 4       0.05610         0.853   0.606          0.000000   1.0    -4.596
#
#    speechiness    tempo  time_signature  valence
# 0       0.1210  125.461             4.0    0.810
# 1       0.1140  143.040             4.0    0.924
# 2       0.2100   99.259             4.0    0.701
# 3       0.1400  100.972             4.0    0.818
# 4       0.0713   94.759             4.0    0.654

# %%
tracks = pd.read_csv("data/formatted/tracks.csv", usecols=["tid", "track_uri", "track_name", "artist_name"])

# %%
tracks_metadata.head().merge(tracks, on="track_uri", how="left").T
# Out:
#                                                            0  \
# track_uri               spotify:track:0UaMYEvWZi0ZqiDOoHU3YI
# popularity                                                63
# realease_year                                           2005
# acousticness                                          0.0311
# danceability                                           0.904
# energy                                                 0.813
# instrumentalness                                     0.00697
# mode                                                       0
# loudness                                              -7.105
# speechiness                                            0.121
# tempo                                                125.461
# time_signature                                             4
# valence                                                 0.81
# tid                                                        0
# track_name        Lose Control (feat. Ciara & Fat Man Scoop)
# artist_name                                    Missy Elliott
#
#                                                      1  \
# track_uri         spotify:track:6I9VzXrHxO9rA9A5euc8Ak
# popularity                                          77
# realease_year                                     2003
# acousticness                                    0.0249
# danceability                                     0.774
# energy                                           0.838
# instrumentalness                                 0.025
# mode                                                 0
# loudness                                        -3.914
# speechiness                                      0.114
# tempo                                           143.04
# time_signature                                       4
# valence                                          0.924
# tid                                                  1
# track_name                                       Toxic
# artist_name                             Britney Spears
#
#                                                      2  \
# track_uri         spotify:track:0WqIKmW4BTrj3eJFmnCKMv
# popularity                                          58
# realease_year                                     2003
# acousticness                                   0.00238
# danceability                                     0.664
# energy                                           0.758
# instrumentalness                                     0
# mode                                                 0
# loudness                                        -6.583
# speechiness                                       0.21
# tempo                                           99.259
# time_signature                                       4
# valence                                          0.701
# tid                                                  2
# track_name                               Crazy In Love
# artist_name                                    Beyoncé
#
#                                                      3  \
# track_uri         spotify:track:1AWQoqb9bSvzTjaLralEkT
# popularity                                          71
# realease_year                                     2002
# acousticness                                     0.202
# danceability                                     0.891
# energy                                           0.714
# instrumentalness                              0.000234
# mode                                                 0
# loudness                                        -6.055
# speechiness                                       0.14
# tempo                                          100.972
# time_signature                                       4
# valence                                          0.818
# tid                                                  3
# track_name                              Rock Your Body
# artist_name                          Justin Timberlake
#
#                                                      4
# track_uri         spotify:track:1lzr43nnXAijIGYnCT8M8H
# popularity                                          27
# realease_year                                     2000
# acousticness                                    0.0561
# danceability                                     0.853
# energy                                           0.606
# instrumentalness                                     0
# mode                                                 1
# loudness                                        -4.596
# speechiness                                     0.0713
# tempo                                           94.759
# time_signature                                       4
# valence                                          0.654
# tid                                                  4
# track_name                                It Wasn't Me
# artist_name                                     Shaggy

# %%
tracks_metadata.loc[tracks_metadata["energy"]==1, ["track_uri", "energy"]].merge(tracks, on="track_uri", how="left")
# Out:
#                                 track_uri  energy      tid  \
# 0    spotify:track:4YP5IwwbQEDUgDCG5jNmDq     1.0     7260
# 1    spotify:track:7vHaqMmt5DGacX6c6YCuCP     1.0    64049
# 2    spotify:track:3hdeTHLlna8eJwnOiBVoOi     1.0    93701
# 3    spotify:track:1U7j5xpUSgX0gxk5lmhHUD     1.0    98944
# 4    spotify:track:1z2Kf0DhuJqG7bwP02oqiP     1.0   114763
# 557                              Pulser - Original Mix
# 558                            Gop Fm - DJ Pelix Remix
# 559                                   Bumping-Hardbass
# 560                                Pouring Rain Sounds
# 561                           Rain Sound: Forest Chill
# 562                                     Afternoon Rain
# 563                                      Hillside Rain
# 564                                   White Noise Rain
# 565                             Shelter from the Storm
# 566                                        Sleepy Rain
# 567                                  The End of Summer
# 568                                        Autumn Rain
# 569                                       Pouring Rain
# 570                                   Rain and Thunder
# 571                                  Relaxing Rainfall
# 572                               Relaxing Forest Rain
# 573                                   Rain Heavy Rural
# 574                                          Slow Rain
# 575                                    Cold Rain Drops
# 576                                Big Raindrop - Loop
# 577                                 Very Slow Raindrop
# 578                                          Fast Rain
# 579                                           Weather1
# 580                                   Rain Never Stops
# 581                                     Even More Rain
# 582                                      Ice Cold Rain
# 583                                        Harsh Rains
# 584                                          Rain Hide
# 585                                   Local Rain Birds
#
#                                            artist_name
# 0                                          Ryan Miller
# 1                                        Nature Sounds
# 2                                               Parser
# 3                                       Gopnik McBlyat
# 4                                             DJ Hulpa
# 5                                 Mike Der Bademeister
# 6                                                  Non
# 7                                           Basshunter
# 8          Lighting, Thunderstorms & Rain Storm Sounds
# 9                           Nature Sounds Nature Music
# 10                                             RMaster
# 11   Sounds of Nature White Noise for Mindfulness M...
# 12   Sounds of Nature White Noise for Mindfulness M...
# 13   Sounds of Nature White Noise for Mindfulness M...
# 14                                           Spa & Spa
# 15                                   Brown Noise Radio
# 16                                   Brown Noise Radio
# 17                                   Brown Noise Radio
# 18                                   Brown Noise Radio
# 19                                 Power Music Workout
# 20                                    Kathleen Madigan
# 21   Soothing White Noise for Infant Sleeping and M...
# 22   Soothing White Noise for Infant Sleeping and M...
# 23                              Out of Body Experience
# 24                                               Tobee
# 25                                       Sound Dreamer
# 26                                       Sound Dreamer
# 27                                          Marc Smith
# 28                                                 USK
# 29                              Nature Sounds Research
# ..                                                 ...
# 556                                         XS Project
# 557                                   OBSIDIAN Project
# 558                                   Hard Bass School
# 559                                        UsDexx Dj's
# 560                            Rain Sounds XLE Library
# 561                            Rain Sounds XLE Library
# 562                                         Rain Sound
# 563                                         Rain Sound
# 564                                         Rain Sound
# 565                                         Rain Sound
# 566                                         Rain Sound
# 567                                         Rain Sound
# 568                                         Rain Sound
# 569                                         Rain Sound
# 570                                         Rain Sound
# 571                                         Rain Sound
# 572                                  Baby Sleep Sounds
# 573                                  Baby Sleep Sounds
# 574                                  Rain Sounds Sleep
# 575                                        Rain Sounds
# 576                              Meditation Music Zone
# 577                                        Rain Sounds
# 578                                    Raindrops Sleep
# 579                                        Rain Sounds
# 580                                        Rain Sounds
# 581                          Rain Sounds Factory STHLM
# 582                                         Sleep Rain
# 583                                      Thunderstorms
# 584                                  Rain Sounds Sleep
# 585                                        Rain Sounds
#
# [586 rows x 5 columns]

# %% [markdown]
# <hr>
