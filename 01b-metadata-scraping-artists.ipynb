# %% [markdown]
# # Metadata Scraping - Artists
#
# Os dados fornecidos pelo Spotify são bastante secos em termos de catergorização das músicas presentes em cada uma das playlists. Em uma estratégia utilizando puramente técnicas de Filtro Colaborativo, que é nosso foco neste projeto, isso seria suficiente. Mas buscaremos observar também técnicas relacionadas sistemas Baseados em Conteúdo, bem como estratégias híbridas, bem como será interessante analisar alguns padrões nas diversas listagens disponíveis.
#
# Assim, no presente notebook, nos utilizamos do módulo [Spotipy](https://spotipy.readthedocs.io/en/latest/) para nos utilizar de dados do Spotify para enriquecer nossa base de dados.
#
# Dados de <b>ARTISTAS</b>
# <br><br>
# <hr>
# @author: [Pedro Correia](https://github.com/pfcor)

# %%
import math
import pprint
from collections import defaultdict
import pandas as pd
import numpy as np
import tqdm
import time
import datetime as dt
import os

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# Vamos iterar faixa a faixa e obter informações relacionadas ao artista (estilos, popularidade, número de seguidores e artistas similares)e à música (níveis de ritmos, instrumentação, etc)

# %%
def spotipy_auth():
    
    # initializing and authenticating
    from spotipy_credencials import CLIENT_ID, CLIENT_SECRET
    ccm = SpotifyClientCredentials( client_id=CLIENT_ID, client_secret=CLIENT_SECRET )
    sp = spotipy.Spotify(client_credentials_manager=ccm)
    return sp


def get_artists_uri():
    
    return pd.read_csv("tab_data/tracks_metadata.csv", usecols=["artist_uri"])["artist_uri"].unique()


def get_top_n_related_artists(artist_uri, n=3, sort_by="popularity", include_name=False):
    
    assert sort_by in ["popularity", "similarity"]
    
    related_artists = [
        (rartist["uri"], rartist["name"], rartist["popularity"]) 
        for rartist 
        in sp.artist_related_artists(artist_uri)["artists"]
    ]
    
    if sort_by=="popularity":
        related_artists = sorted(related_artists, key=lambda x: -x[-1])[:n]
    
    return [rartist[:2] if include_name else rartist[0] for rartist in related_artists[:n]]

# %%
def scrape_artist_metadata(batch_size=50, output_folder="data/metadata"):
    
    print("|Initializing Spotify API...", end=" ", flush=True)
    sp = spotipy_auth()
    print("ok\n")
    
    print("|Loading artists...", end=" ", flush=True)
    artists = get_artists_uri()
    n_artists = len(artists)
    print("ok")
    
    print(f"    > {n_artists} artists to be processed\n")
    
    print("|Gathering Spotify data")
    t0 = time.time()
    
    spotify_data = defaultdict(list)

    batches_count = math.ceil(n_artists / batch_size)
    print(f"    > {batches_count} batches to be processed")
    
    for i in range(batches_count):

        i_0 = i * batch_size
        i_f = i_0 + batch_size           
        batch = artists[i_0:i_f]
        
        # general data
        artists_data = sp.artists(batch)["artists"]
        
        for artist in artists_data:
        
            if artist != None:
                spotify_data['artist_uri'].append(artist['uri'])
                spotify_data['popularity'].append(artist['popularity'])
                spotify_data['genres'].append(artist["genres"])
#                 spotify_data["related_artists"].append(get_top_n_related_artists(artist["uri"]))
            else:
                spotify_data['artist_uri'].append(np.nan)
                spotify_data['popularity'].append(np.nan)
                spotify_data['genres'].append(np.nan)
#                 spotify_data["related_artists"].append(np.nan)
          
        if ((i+1)%100 == 0) or ((i+1) == batches_count):
            print(f'        - {i+1:>8} batches completed | {batches_count-(i+1):>8} to go | elapsed time: {str(dt.timedelta(seconds=time.time()-t0))}')
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    filename = output_folder + '/artists_metadata.csv'
    print(f"    > Saving to file: {filename}")
    spotify_data = pd.DataFrame(spotify_data)
    spotify_data.to_csv(filename, index=False, sep=";")

# %%
scrape_artist_metadata()
# Out:
# |Initializing Spotify API... ok
#
# |Loading artists... ok
#     > 295860 artists to be processed
#
# |Gathering Spotify data
#     > 5918 batches to be processed
#         -      100 batches completed |     5818 to go | elapsed time: 0:00:59.097345
#         -      200 batches completed |     5718 to go | elapsed time: 0:01:48.905869
#         -      300 batches completed |     5618 to go | elapsed time: 0:02:39.463112
#         -      400 batches completed |     5518 to go | elapsed time: 0:03:34.307537
#         -      500 batches completed |     5418 to go | elapsed time: 0:04:26.294466
#         -      600 batches completed |     5318 to go | elapsed time: 0:05:33.564779
#         -      700 batches completed |     5218 to go | elapsed time: 0:06:48.684547
#         -      800 batches completed |     5118 to go | elapsed time: 0:08:37.356402
#         -      900 batches completed |     5018 to go | elapsed time: 0:09:49.841457
#         -     1000 batches completed |     4918 to go | elapsed time: 0:10:54.127287
#         -     1100 batches completed |     4818 to go | elapsed time: 0:11:51.270966
#         -     1200 batches completed |     4718 to go | elapsed time: 0:12:44.811620
#         -     1300 batches completed |     4618 to go | elapsed time: 0:13:46.938132
#         -     1400 batches completed |     4518 to go | elapsed time: 0:15:07.413841
#         -     1500 batches completed |     4418 to go | elapsed time: 0:16:08.557387
#         -     1600 batches completed |     4318 to go | elapsed time: 0:17:05.781468
#         -     1700 batches completed |     4218 to go | elapsed time: 0:18:17.446893
#         -     1800 batches completed |     4118 to go | elapsed time: 0:19:11.409321
#         -     1900 batches completed |     4018 to go | elapsed time: 0:20:13.528436
#         -     2000 batches completed |     3918 to go | elapsed time: 0:21:20.281982
#         -     2100 batches completed |     3818 to go | elapsed time: 0:22:01.801194
#         -     2200 batches completed |     3718 to go | elapsed time: 0:22:49.907695
#         -     2300 batches completed |     3618 to go | elapsed time: 0:23:48.935959
#         -     2400 batches completed |     3518 to go | elapsed time: 0:24:25.934424
#         -     2500 batches completed |     3418 to go | elapsed time: 0:25:19.892876
#         -     2600 batches completed |     3318 to go | elapsed time: 0:26:12.848328
#         -     2700 batches completed |     3218 to go | elapsed time: 0:27:18.813382
#         -     2800 batches completed |     3118 to go | elapsed time: 0:28:05.666089
#         -     2900 batches completed |     3018 to go | elapsed time: 0:28:55.074884
#         -     3000 batches completed |     2918 to go | elapsed time: 0:29:53.192858
#         -     3100 batches completed |     2818 to go | elapsed time: 0:30:48.690372
#         -     3200 batches completed |     2718 to go | elapsed time: 0:31:41.410944
#         -     3300 batches completed |     2618 to go | elapsed time: 0:32:47.582183
#         -     3400 batches completed |     2518 to go | elapsed time: 0:34:02.169471
#         -     3500 batches completed |     2418 to go | elapsed time: 0:34:44.542727
#         -     3600 batches completed |     2318 to go | elapsed time: 0:35:57.537838
#         -     3700 batches completed |     2218 to go | elapsed time: 0:37:28.975810
#         -     3800 batches completed |     2118 to go | elapsed time: 0:38:38.431289
#         -     3900 batches completed |     2018 to go | elapsed time: 0:40:03.230860
#         -     4000 batches completed |     1918 to go | elapsed time: 0:41:11.312255
#         -     4100 batches completed |     1818 to go | elapsed time: 0:42:37.915762
#         -     4200 batches completed |     1718 to go | elapsed time: 0:45:24.650549
#         -     4300 batches completed |     1618 to go | elapsed time: 0:46:49.597433
#         -     4400 batches completed |     1518 to go | elapsed time: 0:47:58.943468
#         -     4500 batches completed |     1418 to go | elapsed time: 0:49:33.135133
#         -     4600 batches completed |     1318 to go | elapsed time: 0:50:35.168966
#         -     4700 batches completed |     1218 to go | elapsed time: 0:51:29.508873
#         -     4800 batches completed |     1118 to go | elapsed time: 0:52:26.823125
#         -     4900 batches completed |     1018 to go | elapsed time: 0:53:21.591663
#         -     5000 batches completed |      918 to go | elapsed time: 0:54:35.097824
#         -     5100 batches completed |      818 to go | elapsed time: 0:56:41.836781
#         -     5200 batches completed |      718 to go | elapsed time: 0:57:49.685371
#         -     5300 batches completed |      618 to go | elapsed time: 0:58:43.521237
#         -     5400 batches completed |      518 to go | elapsed time: 0:59:41.461129
#         -     5500 batches completed |      418 to go | elapsed time: 1:00:37.812137
#         -     5600 batches completed |      318 to go | elapsed time: 1:01:29.741262
#         -     5700 batches completed |      218 to go | elapsed time: 1:02:36.048645
#         -     5800 batches completed |      118 to go | elapsed time: 1:03:33.686617
#         -     5900 batches completed |       18 to go | elapsed time: 1:04:28.146592
#         -     5918 batches completed |        0 to go | elapsed time: 1:05:15.034283
#     > Saving to file: data/metadata/artists_metadata.csv

# %% [markdown]
# <hr>

# %%
artists_metadata = pd.read_csv("data/metadata/artists_metadata.csv", sep=";")

# %%
artists_metadata["genres"][0]
# Out:
# "['dance pop', 'hip hop', 'hip pop', 'pop', 'pop rap', 'r&b', 'rap', 'southern hip hop', 'urban contemporary']"

# %%
import ast

# %%
ast.literal_eval(artists_metadata["genres"][0])
# Out:
# ['dance pop',
#  'hip hop',
#  'hip pop',
#  'pop',
#  'pop rap',
#  'r&b',
#  'rap',
#  'southern hip hop',
#  'urban contemporary']

# %%
from collections import Counter

# %%
genders_counter = Counter()

# %%
genders_counter = Counter()
for genres in artists_metadata["genres"].values:
    genders_counter.update(ast.literal_eval(genres))

# %%
genders_counter
# Out:
# Counter({'dance pop': 599,
#          'hip hop': 501,
#          'hip pop': 270,
#          'pop': 571,
#          'pop rap': 454,
#          'r&b': 339,
#          'rap': 474,
#          'southern hip hop': 368,
#          'urban contemporary': 379,
#          'post-teen pop': 351,
#          'reggae fusion': 82,
#          'australian pop': 183,
#          'girl group': 60,
#          'dirty south rap': 275,
#          'canadian pop': 107,
#          'pop rock': 364,
#          'neo mellow': 274,
#          'viral pop': 197,
#          'deep pop r&b': 237,
#          'candy pop': 100,
#          'folk': 359,
#          'folk-pop': 500,
#          'lilith': 247,
#          'mellow gold': 330,
#          'new wave pop': 340,
#          'permanent wave': 110,
#          'rock': 568,
#          'comic': 224,
#          'pop punk': 294,
#          'post-grunge': 294,
#          'boy band': 92,
#          'emo': 342,
#          'pixie': 138,
#          'pop emo': 186,
#          'trap queen': 114,
#          'bubblegum dance': 194,
#          'eurodance': 170,
#          'europop': 311,
#          'german techno': 164,
#          'pinoy hip hop': 66,
#          'electropop': 309,
#          'escape room': 271,
#          'new rave': 229,
#          'indie rock': 423,
#          'modern rock': 527,
#          'punk': 260,
#          'piano rock': 110,
#          'indie pop rap': 148,
#          'album rock': 321,
#          'hard rock': 319,
#          'soft rock': 318,
#          'otacore': 266,
#          'scorecore': 303,
#          'video game music': 188,
#          'british soundtrack': 78,
#          'broadway': 224,
#          'hollywood': 232,
#          'show tunes': 231,
#          'vocal jazz': 248,
#          'classic rock': 297,
#          'alternative metal': 321,
#          'alternative rock': 357,
#          'nu metal': 276,
#          'finnish metal': 87,
#          'gothic metal': 158,
#          'gothic symphonic metal': 132,
#          'power metal': 180,
#          'progressive metal': 233,
#          'symphonic metal': 122,
#          'british invasion': 85,
#          'protopunk': 93,
#          'blues-rock': 264,
#          'southern rock': 214,
#          'art rock': 322,
#          'folk rock': 368,
#          'bow pop': 94,
#          'heartland rock': 92,
#          'progressive rock': 160,
#          'symphonic rock': 195,
#          'glam rock': 81,
#          'glam metal': 175,
#          'roots rock': 320,
#          'german metal': 110,
#          'german rock': 201,
#          'metal': 305,
#          'canadian metal': 89,
#          'classic canadian rock': 65,
#          'k-indie': 188,
#          'k-pop': 309,
#          'korean pop': 294,
#          'korean r&b': 72,
#          'k-hop': 99,
#          'j-pop': 91,
#          'classical': 221,
#          'late romantic era': 90,
#          'indie garage rock': 238,
#          'indie psych-rock': 286,
#          'indie surf': 67,
#          'lo-fi beats': 240,
#          'bedroom pop': 41,
#          'dance rock': 310,
#          'new romantic': 215,
#          'new wave': 277,
#          'synthpop': 105,
#          'preverb': 351,
#          'chillwave': 235,
#          'dream pop': 208,
#          'experimental pop': 104,
#          'indietronica': 476,
#          'neo-psychedelic': 370,
#          'noise pop': 268,
#          'nu gaze': 230,
#          'vaporwave': 147,
#          'art pop': 266,
#          'indie r&b': 384,
#          'aussietronica': 202,
#          'australian alternative rock': 140,
#          'deep australian indie': 235,
#          'alternative dance': 230,
#          'brooklyn indie': 151,
#          'indie pop': 363,
#          'shoegaze': 169,
#          'indie punk': 258,
#          'power-pop punk': 108,
#          'riot grrrl': 88,
#          'dance-punk': 277,
#          'garage rock': 360,
#          'anti-folk': 109,
#          'chamber pop': 368,
#          'freak folk': 350,
#          'garage psych': 216,
#          'indie folk': 349,
#          'lo-fi': 236,
#          'new americana': 337,
#          'slow core': 184,
#          'stomp and holler': 343,
#          'new weird america': 195,
#          'shimmer pop': 248,
#          'garage pop': 144,
#          'noise rock': 218,
#          'nashville indie': 43,
#          'alternative pop rock': 90,
#          'modern alternative rock': 344,
#          'funk': 381,
#          'philly indie': 108,
#          'alternative country': 195,
#          'jam band': 162,
#          'melancholia': 157,
#          'indie poptimism': 411,
#          'vapor soul': 393,
#          'underground hip hop': 374,
#          'canadian hip hop': 148,
#          'emo rap': 144,
#          'future funk': 149,
#          'bay area indie': 87,
#          'experimental': 184,
#          'experimental rock': 202,
#          'grave wave': 160,
#          'industrial': 169,
#          'post-rock': 190,
#          'metropopolis': 188,
#          'neo-synthpop': 142,
#          'kiwi rock': 117,
#          'grunge': 114,
#          'funk rock': 49,
#          'neo soul': 262,
#          'new jack swing': 197,
#          'quiet storm': 282,
#          'zolo': 71,
#          'small room': 90,
#          'singer-songwriter': 127,
#          'alternative pop': 133,
#          'gbvfi': 114,
#          'hardcore punk': 152,
#          'jangle pop': 168,
#          'math rock': 110,
#          'post-hardcore': 223,
#          'post-punk': 178,
#          'power pop': 157,
#          'uk post-punk': 187,
#          'mod revival': 38,
#          'psychedelic blues-rock': 100,
#          'krautrock': 59,
#          'psychedelic rock': 257,
#          'conscious hip hop': 139,
#          'uk alternative hip hop': 129,
#          'uk hip hop': 185,
#          'alternative hip hop': 289,
#          'east coast hip hop': 162,
#          'gangster rap': 327,
#          'hardcore hip hop': 259,
#          'turntablism': 170,
#          'abstract hip hop': 157,
#          'chicago indie': 83,
#          'soul': 272,
#          'adult standards': 349,
#          'christmas': 373,
#          'jazz blues': 56,
#          'soul blues': 77,
#          'emo punk': 130,
#          'folk punk': 146,
#          'melodic hardcore': 277,
#          'orgcore': 155,
#          'skate punk': 189,
#          'chicago punk': 61,
#          'newfoundland indie': 11,
#          'pinoy indie': 106,
#          'no wave': 139,
#          'britpop': 173,
#          'madchester': 40,
#          'maskandi': 6,
#          'ectofolk': 79,
#          'hip house': 245,
#          'classic soul': 248,
#          'disco': 262,
#          'motown': 236,
#          'southern soul': 200,
#          'edm': 452,
#          'old school hip hop': 99,
#          'kids dance party': 49,
#          'brill building pop': 261,
#          'electro': 196,
#          'electronic': 246,
#          'filter house': 174,
#          'latin': 477,
#          'pop quebecois': 68,
#          'miami bass': 74,
#          'reggae': 197,
#          'roots reggae': 245,
#          'acoustic pop': 202,
#          'contemporary country': 279,
#          'country': 266,
#          'country road': 230,
#          'big room': 261,
#          'brostep': 241,
#          'electro house': 485,
#          'house': 337,
#          'trance': 204,
#          'tropical house': 325,
#          'west coast rap': 100,
#          'modern country rock': 210,
#          'uk funky': 37,
#          'progressive house': 347,
#          'latin pop': 324,
#          'latin viral pop': 228,
#          'reggaeton': 89,
#          'portland indie': 86,
#          'funk metal': 79,
#          'stoner metal': 171,
#          'stoner rock': 168,
#          'irish rock': 73,
#          'horror punk': 90,
#          'australian dance': 98,
#          'sheffield indie': 32,
#          'ninja': 141,
#          'indie anthem-folk': 242,
#          'vapor pop': 141,
#          'canadian contemporary r&b': 46,
#          'trap soul': 174,
#          'australian reggae fusion': 34,
#          'etherpop': 98,
#          'alternative r&b': 85,
#          'downtempo': 104,
#          'microhouse': 249,
#          'nu disco': 164,
#          'welsh rock': 36,
#          'liquid funk': 189,
#          'dutch pop': 170,
#          'norwegian indie': 126,
#          'norwegian pop': 199,
#          'nu jazz': 246,
#          'trip hop': 228,
#          'vapor twitch': 223,
#          'detroit hip hop': 65,
#          'trap music': 334,
#          'chillstep': 171,
#          'drum and bass': 199,
#          'stomp pop': 113,
#          'punk blues': 169,
#          'la indie': 111,
#          'merseybeat': 160,
#          'reggae rock': 154,
#          'uk reggae': 53,
#          'bubblegum pop': 226,
#          'rock-and-roll': 224,
#          'nashville sound': 204,
#          'outlaw country': 288,
#          'texas country': 188,
#          'traditional country': 221,
#          'modern southern rock': 72,
#          'canadian contemporary country': 205,
#          'country rock': 223,
#          'redneck': 179,
#          'red dirt': 201,
#          'roots americana': 139,
#          'country gospel': 257,
#          'cowboy western': 170,
#          'viral trap': 77,
#          'crunk': 53,
#          'memphis hip hop': 60,
#          'rap rock': 193,
#          'detroit trap': 78,
#          'vapor trap': 229,
#          'austindie': 96,
#          'glitch hop': 115,
#          'retro electro': 177,
#          'gothenburg indie': 49,
#          'swedish electropop': 64,
#          'swedish synthpop': 81,
#          'chill lounge': 153,
#          'acid jazz': 189,
#          'swedish indie pop': 104,
#          'swedish pop': 260,
#          'bass music': 192,
#          'electra': 129,
#          'big beat': 144,
#          'electro swing': 198,
#          'wonky': 169,
#          'jazz rap': 95,
#          'glitch': 74,
#          'intelligent dance music': 142,
#          'drill and bass': 101,
#          'witch house': 81,
#          'wave': 122,
#          'moombahton': 112,
#          'electronica': 64,
#          'italian alternative': 77,
#          'latintronica': 53,
#          'catstep': 187,
#          'substep': 127,
#          'bmore': 54,
#          'laboratorio': 71,
#          'dubstep': 123,
#          'future garage': 154,
#          'hauntology': 70,
#          'uk garage': 99,
#          'tango': 121,
#          'swedish alternative rock': 146,
#          'electro jazz': 145,
#          'complextro': 170,
#          'filthstep': 149,
#          'indie jazz': 168,
#          'digital hardcore': 17,
#          'nintendocore': 92,
#          'electronic trap': 217,
#          'deep liquid': 90,
#          'canadian indie': 172,
#          'ska': 190,
#          'ska punk': 164,
#          'german pop': 227,
#          'deep tropical house': 271,
#          'lounge': 277,
#          'neo-singer-songwriter': 19,
#          'talent show': 55,
#          'canadian rock': 81,
#          'anarcho-punk': 32,
#          'industrial metal': 195,
#          'industrial rock': 172,
#          'cyberpunk': 63,
#          'ska mexicano': 52,
#          'stomp and flutter': 54,
#          'scottish indie': 81,
#          'twee pop': 148,
#          'albuquerque indie': 20,
#          'popgaze': 115,
#          'canadian punk': 62,
#          'crossover thrash': 190,
#          'quebec indie': 54,
#          'modern blues rock': 220,
#          'scottish rock': 91,
#          'alternative emo': 204,
#          'new jersey indie': 76,
#          'lgbtq+ hip hop': 54,
#          'indie rockism': 154,
#          'gauze pop': 94,
#          'screamo': 253,
#          'dark post-punk': 115,
#          'indie dream pop': 140,
#          'shimmer psych': 74,
#          'anthem emo': 230,
#          'dreamo': 168,
#          'irish singer-songwriter': 46,
#          'anthem worship': 308,
#          'ccm': 217,
#          'christian alternative rock': 242,
#          'christian music': 236,
#          'christian rock': 226,
#          'worship': 263,
#          'northern irish indie': 31,
#          'progressive electro house': 245,
#          'disco house': 187,
#          'vocal house': 205,
#          'rock cristiano': 72,
#          'world worship': 215,
#          'deep talent show': 133,
#          'indiecoustica': 216,
#          'latin alternative': 305,
#          'mexican pop': 120,
#          'rock en espanol': 349,
#          'lift kit': 215,
#          'modern hard rock': 135,
#          'british folk': 108,
#          'traditional folk': 218,
#          'deep new americana': 322,
#          'seattle indie': 66,
#          'electric blues': 226,
#          'modern blues': 200,
#          'mashup': 27,
#          'progressive bluegrass': 189,
#          'swedish americana': 34,
#          'swedish singer-songwriter': 47,
#          'scottish singer-songwriter': 40,
#          'canadian folk': 101,
#          'saskatchewan indie': 16,
#          'louisville indie': 40,
#          'shiver pop': 101,
#          'memphis soul': 79,
#          'abstract beats': 82,
#          'western swing': 142,
#          'fingerstyle': 118,
#          'deep trap': 119,
#          'tejano': 163,
#          'rockabilly': 211,
#          'british blues': 100,
#          'egyptian pop': 48,
#          'hard alternative': 146,
#          'post-screamo': 247,
#          'groove metal': 243,
#          'rap metal': 53,
#          'melodic metalcore': 248,
#          'metalcore': 314,
#          'speed metal': 254,
#          'thrash metal': 130,
#          'deep big room': 247,
#          'deep groove house': 257,
#          'bass trap': 199,
#          'electroclash': 99,
#          'minimal techno': 273,
#          'tech house': 345,
#          'brazilian electronica': 179,
#          'bluegrass': 169,
#          'icelandic indie': 60,
#          'afropop': 296,
#          'desert blues': 48,
#          'mande pop': 124,
#          'world': 162,
#          'bulgarian hip hop': 22,
#          'g funk': 87,
#          'hands up': 152,
#          'italo dance': 27,
#          'teen pop': 150,
#          'chamber psych': 224,
#          'indie psych-pop': 72,
#          'vancouver indie': 108,
#          'vancouver punk': 70,
#          'modern ska punk': 127,
#          'deep euro house': 122,
#          'deep house': 279,
#          'deep pop edm': 204,
#          'commons': 31,
#          'tropical pop edm': 158,
#          'a cappella': 169,
#          'norwegian hip hop': 74,
#          'danish pop': 196,
#          'canadian ccm': 36,
#          'christian punk': 117,
#          'country dawn': 158,
#          'channel pop': 173,
#          'boston hardcore': 51,
#          'c-pop': 221,
#          'chinese audiophile': 39,
#          'chinese indie': 111,
#          'chinese jazz': 7,
#          'mandopop': 241,
#          'bolero': 197,
#          'acoustic blues': 66,
#          'appalachian folk': 131,
#          'blues': 208,
#          'country blues': 88,
#          'delta blues': 55,
#          'texas blues': 61,
#          'traditional blues': 177,
#          'flamenco': 169,
#          'flamenco guitar': 121,
#          'rumba': 172,
#          'latin jazz': 201,
#          'jazz funk': 249,
#          'bossa nova': 214,
#          'hyphy': 141,
#          'west coast trap': 215,
#          'melbourne bounce': 77,
#          'swing': 214,
#          'dutch hip hop': 115,
#          'deep dance pop': 56,
#          'j-idol': 48,
#          'electropowerpop': 67,
#          'tracestep': 213,
#          'dutch house': 57,
#          'sky room': 249,
#          'ontario indie': 36,
#          'math pop': 103,
#          'afrobeats': 145,
#          'azontobeats': 213,
#          'nigerian hip hop': 66,
#          'african gospel': 66,
#          'soukous': 76,
#          'afro house': 112,
#          'gqom': 18,
#          'kwaito house': 88,
#          'south african pop': 148,
#          'azonto': 93,
#          'south african hip hop': 41,
#          'bongo flava': 44,
#          'australian country': 39,
#          'soundtrack': 211,
#          'northern soul': 86,
#          'old-time': 145,
#          'nasheed': 38,
#          'banjo': 161,
#          'idol': 71,
#          'fake': 215,
#          'canadian country': 110,
#          'celtic rock': 104,
#          'christian hip hop': 184,
#          'christian trap': 158,
#          'edmonton indie': 43,
#          'israeli indie': 34,
#          'praise': 255,
#          'gospel': 159,
#          'naija worship': 62,
#          'classify': 187,
#          'easy listening': 179,
#          'cabaret': 219,
#          'operatic pop': 104,
#          'grime': 189,
#          'chicano rap': 172,
#          'latin hip hop': 253,
#          'battle rap': 71,
#          'deep southern trap': 191,
#          'drill': 84,
#          'jazz trumpet': 150,
#          'instrumental funk': 91,
#          'dirty texas rap': 76,
#          'deep underground hip hop': 334,
#          'desi': 234,
#          'indian pop': 212,
#          'italian disco': 124,
#          'nz hip hop': 39,
#          'underground rap': 200,
#          'french hip hop': 239,
#          'french rock': 209,
#          'african rock': 77,
#          'dark wave': 152,
#          'breakbeat': 105,
#          'outsider': 74,
#          'danish electro-pop': 42,
#          'j-rap': 58,
#          'indonesian hip hop': 18,
#          'pub rock': 161,
#          'native american': 99,
#          'chicago soul': 42,
#          'doo-wop': 181,
#          'p funk': 40,
#          'classic girl group': 44,
#          'post-disco': 201,
#          'disney': 88,
#          'movie tunes': 165,
#          'deep adult standards': 84,
#          'vocal harmony group': 82,
#          'swedish hard rock': 29,
#          'australian rock': 125,
#          "children's music": 118,
#          'antiviral pop': 176,
#          'epicore': 178,
#          'theme': 92,
#          "canadian children's music": 14,
#          "children's folk": 50,
#          'finnish edm': 36,
#          'bhangra': 136,
#          'desi hip hop': 288,
#          'filmi': 295,
#          'modern bollywood': 211,
#          'punjabi': 148,
#          'sufi': 194,
#          'wrestling': 71,
#          'classic soundtrack': 94,
#          'italian soundtrack': 17,
#          'vintage italian soundtrack': 60,
#          'deep chiptune': 196,
#          'eurobeat': 13,
#          'belgian modern jazz': 11,
#          'belgian dance': 28,
#          'french indie pop': 187,
#          'french indietronica': 184,
#          'indie electro-pop': 217,
#          'boston hip hop': 45,
#          'christian uplift': 128,
#          'garage punk': 101,
#          'c86': 128,
#          'progressive post-hardcore': 168,
#          'christian hardcore': 118,
#          'toronto indie': 79,
#          'puerto rican indie': 51,
#          'australian garage punk': 115,
#          'kawaii future bass': 33,
#          'latin afrobeat': 43,
#          'puerto rican rock': 50,
#          'tropical': 406,
#          'bachata': 81,
#          'cumbia': 241,
#          'grupera': 329,
#          'latin arena pop': 120,
#          'latin rock': 378,
#          'mexican rock': 193,
#          'cuban rumba': 189,
#          'mambo': 203,
#          'salsa': 84,
#          'reggaeton flow': 240,
#          'merengue': 45,
#          'pop house': 109,
#          'colombian pop': 57,
#          'pop reggaeton': 220,
#          'nu-cumbia': 61,
#          'mexican rock-and-roll': 103,
#          'ranchera': 234,
#          'banda': 291,
#          'norteno': 245,
#          'regional mexican': 277,
#          'electro latino': 70,
#          'spanish pop': 219,
#          'spanish pop rock': 72,
#          'argentine rock': 188,
#          'rock nacional': 82,
#          'ska argentino': 38,
#          'panamanian pop': 76,
#          'trap latino': 46,
#          'rap dominicano': 57,
#          'cumbia salvadorena': 53,
#          'deep cumbia sonidera': 133,
#          'cumbia sonidera': 139,
#          'duranguense': 212,
#          'mariachi': 158,
#          'chicha': 64,
#          'axe': 118,
#          'pagode': 201,
#          'deep ccm': 151,
#          'jawaiian': 186,
#          'polynesian pop': 124,
#          'compositional ambient': 236,
#          'ambient idm': 90,
#          'russian electronic': 32,
#          'uk contemporary r&b': 84,
#          'focus': 267,
#          'icelandic classical': 22,
#          'neoclassical': 125,
#          'hindustani classical': 73,
#          'hindustani instrumental': 34,
#          'indian classical': 127,
#          'healing': 195,
#          'kirtan': 151,
#          'meditation': 169,
#          'new tribe': 92,
#          'world fusion': 116,
#          'singaporean mandopop': 23,
#          'singaporean pop': 48,
#          'cantopop': 169,
#          'malaysian pop': 74,
#          'malaysian mandopop': 33,
#          'mainland chinese pop': 80,
#          'classic mandopop': 132,
#          'hawaiian': 159,
#          'dub': 191,
#          'dancehall': 265,
#          'gospel rap': 70,
#          'german soundtrack': 23,
#          'ghazal': 64,
#          'indian folk': 176,
#          'pakistani pop': 112,
#          'qawwali': 55,
#          'indian indie': 66,
#          'ghanaian hip hop': 29,
#          'freestyle': 123,
#          'boston rock': 103,
#          'smooth jazz': 174,
#          'mexican electronic': 10,
#          'hi-nrg': 56,
#          'ska revival': 87,
#          'american folk revival': 65,
#          'louisiana blues': 76,
#          'swamp blues': 28,
#          'swamp pop': 76,
#          'vegas indie': 28,
#          'soca': 158,
#          'comedy': 163,
#          'gypsy jazz': 102,
#          'classical performance': 177,
#          'orchestra': 91,
#          'indie fuzzpop': 87,
#          'classic garage rock': 138,
#          'freakbeat': 133,
#          'rhythm and blues': 208,
#          'exotica': 92,
#          'library music': 89,
#          'spytrack': 45,
#          'surf music': 121,
#          'afrobeat': 138,
#          'soul jazz': 201,
#          'neo classical metal': 196,
#          'karaoke': 189,
#          'argentine reggae': 68,
#          'dominican pop': 30,
#          'champeta': 36,
#          'vallenato': 50,
#          'italian pop': 202,
#          'boogaloo': 175,
#          'cantautor': 222,
#          'classic venezuelan pop': 107,
#          'salsa international': 149,
#          'cubaton': 65,
#          'nueva cancion': 184,
#          'trova': 118,
#          'mexican hip hop': 141,
#          'vocal trance': 43,
#          'diva house': 83,
#          'italo house': 25,
#          'hardstyle': 139,
#          'hardcore techno': 244,
#          'new beat': 26,
#          'bubble trance': 111,
#          'bouncy house': 69,
#          'happy hardcore': 155,
#          'jungle': 145,
#          'progressive trance': 200,
#          'new age': 184,
#          'new age piano': 128,
#          'post-romantic era': 102,
#          'russian romanticism': 33,
#          'ukrainian classical': 7,
#          'russian ccm': 20,
#          'christelijk': 36,
#          'southern gospel': 150,
#          'alternative ccm': 38,
#          'brazilian rock': 172,
#          'manguebeat': 40,
#          'mpb': 227,
#          'rock gaucho': 110,
#          'forro': 191,
#          'samba': 209,
#          'fado': 47,
#          'velha guarda': 121,
#          'latin classical': 62,
#          'brazilian composition': 59,
#          'choro': 89,
#          'baile pop': 178,
#          'nova mpb': 93,
#          'indonesian jazz': 44,
#          'strut': 107,
#          'spanish indie pop': 146,
#          'spanish noise pop': 105,
#          'argentine indie': 119,
#          'balearic': 142,
#          'deathgrass': 49,
#          'chiptune': 78,
#          'minimal tech house': 276,
#          'arab pop': 206,
#          'new orleans blues': 57,
#          'comedy rock': 40,
#          'romanian pop': 141,
#          'barbershop': 64,
#          'country rap': 95,
#          'nwobhm': 108,
#          'halloween': 69,
#          'bounce': 99,
#          'sleaze rock': 110,
#          'classic danish pop': 79,
#          'danish hip hop': 103,
#          'workout product': 63,
#          'uk drill': 61,
#          'lovers rock': 199,
#          'riddim': 140,
#          'celtic punk': 75,
#          'irish folk': 167,
#          'jazz trio': 81,
#          'fourth world': 187,
#          'scottish new wave': 38,
#          'avantgarde metal': 176,
#          'dark jazz': 99,
#          'doom metal': 161,
#          'drone': 158,
#          'drone metal': 121,
#          'instrumental rock': 138,
#          'post-doom metal': 152,
#          'post-metal': 157,
#          'sludge metal': 160,
#          'space rock': 162,
#          'death core': 160,
#          'djent': 163,
#          'mathcore': 161,
#          'early modern classical': 115,
#          'french opera': 23,
#          'native american hip hop': 25,
#          'minneapolis indie': 57,
#          'stomp and whittle': 69,
#          'one-person band': 44,
#          'lo star': 67,
#          'acid house': 132,
#          'ambient': 178,
#          'victoria bc indie': 31,
#          'soul flow': 104,
#          'chillhop': 227,
#          'jazz boom bap': 134,
#          'instrumental post-rock': 96,
#          'british indie rock': 78,
#          'ok indie': 52,
#          'manitoba indie': 39,
#          'uk americana': 33,
#          'acousmatic': 75,
#          'avant-garde': 114,
#          'dub techno': 125,
#          'electroacoustic improvisation': 8,
#          'free improvisation': 123,
#          'j-ambient': 88,
#          'mandible': 138,
#          'warm drone': 141,
#          'celtic': 178,
#          'scottish folk': 38,
#          'acid techno': 21,
#          'ebm': 158,
#          'electro-industrial': 183,
#          'piano blues': 62,
#          'dutch rock': 180,
#          'cool jazz': 210,
#          'ukulele': 47,
#          'jazz electric bass': 87,
#          'jazz fusion': 226,
#          'cello': 63,
#          'swedish indie rock': 71,
#          'boston indie': 63,
#          'funana': 16,
#          'bebop': 203,
#          'contemporary post-bop': 237,
#          'free jazz': 130,
#          'hard bop': 194,
#          'jazz': 194,
#          'jazz saxophone': 188,
#          'big band': 213,
#          'chicago house': 136,
#          'uplifting trance': 225,
#          'lds': 123,
#          'british alternative rock': 50,
#          'bassline': 50,
#          'chicago blues': 79,
#          'southern soul blues': 123,
#          'neo-traditional country': 16,
#          'neue deutsche harte': 104,
#          'danish indie pop': 40,
#          'morna': 53,
#          'portuguese pop': 44,
#          'avant-garde jazz': 126,
#          'japanese jazz': 49,
#          'space age pop': 101,
#          'fluxwork': 188,
#          'canadian modern jazz': 17,
#          'highlife': 100,
#          'west african jazz': 35,
#          'benga': 38,
#          'swedish jazz': 68,
#          'brazilian indie': 115,
#          'belgian pop': 68,
#          'ethio-jazz': 27,
#          'contemporary jazz': 217,
#          'french jazz': 47,
#          'rock steady': 161,
#          'tzadik': 45,
#          'alberta country': 26,
#          'french reggae': 150,
#          'underground power pop': 82,
#          'chanson': 222,
#          'chanson paillarde': 15,
#          'ye ye': 87,
#          'anime': 161,
#          'j-rock': 148,
#          'visual kei': 68,
#          'slow game': 117,
#          'columbus ohio indie': 38,
#          'swedish soul': 44,
#          'latin christian': 183,
#          'latin worship': 182,
#          'papuri': 18,
#          'deep latin christian': 89,
#          'vbs': 47,
#          'deep disco': 99,
#          'jazz piano': 114,
#          'wrock': 37,
#          'athens indie': 58,
#          'indie emo': 26,
#          'christian relaxative': 159,
#          'slc indie': 32,
#          'christmas product': 81,
#          'relaxative': 193,
#          'colombian rock': 80,
#          'ecuadorian pop': 56,
#          'dembow': 51,
#          'jig and reel': 59,
#          'albanian hip hop': 44,
#          'australian hip hop': 110,
#          'chutney': 56,
#          'cowpunk': 43,
#          'turkish jazz': 132,
#          'alternative americana': 27,
#          'classical tenor': 20,
#          'classic italian pop': 174,
#          'latin soundtrack': 28,
#          'destroy techno': 73,
#          'irish country': 95,
#          'zapstep': 217,
#          'psychedelic trance': 118,
#          'brit funk': 26,
#          'irish indie': 35,
#          'trancecore': 79,
#          'gothic alternative': 15,
#          'israeli mediterranean': 189,
#          'israeli pop': 216,
#          'deep disco house': 126,
#          'norwegian pop rap': 93,
#          'easycore': 129,
#          'acoustic punk': 71,
#          'modern uplift': 41,
#          'j-punk': 19,
#          'ethereal wave': 126,
#          'icelandic pop': 95,
#          'icelandic rock': 43,
#          'byzantine': 44,
#          'chamber choir': 27,
#          'liturgical': 48,
#          'neo-trad metal': 126,
#          'michigan indie': 53,
#          'boston punk': 38,
#          'danish alternative rock': 52,
#          'classic swedish pop': 123,
#          'tribute': 61,
#          'boom bap': 119,
#          'string band': 75,
#          'traditional bluegrass': 84,
#          'vintage country folk': 43,
#          'vintage western': 12,
#          'piedmont blues': 44,
#          'memphis blues': 45,
#          'groove room': 139,
#          'swedish idol pop': 199,
#          'dutch indie': 122,
#          'belgian indie': 73,
#          'belgian indie rock': 19,
#          'fidget house': 68,
#          'indie quebecois': 111,
#          'aggrotech': 133,
#          'futurepop': 140,
#          'deep regional mexican': 155,
#          'regional mexican pop': 264,
#          'romanian hip hop': 33,
#          'classic malaysian pop': 41,
#          'zouk': 121,
#          'zouk riddim': 82,
#          'christian dance': 30,
#          'indie pop rock': 38,
#          'belly dance': 109,
#          'k-rock': 28,
#          'barnmusik': 62,
#          'swedish folk pop': 142,
#          'dansband': 44,
#          'danspunk': 81,
#          'nordic folk': 40,
#          'ballroom': 106,
#          'future ambient': 28,
#          'german indie': 134,
#          'english indie rock': 78,
#          'italian opera': 35,
#          'belgian rock': 93,
#          'progressive trance house': 116,
#          'funky tech house': 146,
#          'icelandic electronic': 47,
#          'jump blues': 63,
#          'french movie tunes': 40,
#          'kindermusik': 24,
#          'kleine hoerspiel': 19,
#          'deep contemporary country': 83,
#          'trap argentino': 16,
#          'trap espanol': 95,
#          'spanish hip hop': 111,
#          'progressive uplifting trance': 186,
#          'thrash-groove metal': 15,
#          'rap cristiano': 81,
#          'trival': 39,
#          'orchestral performance': 84,
#          'austrian choir': 3,
#          "children's choir": 32,
#          'choral': 61,
#          'gothic rock': 113,
#          'adoracao': 120,
#          'ambeat': 126,
#          ...})

# %%
genders_counter.most_common(30)
# Out:
# [('dance pop', 599),
#  ('pop', 571),
#  ('rock', 568),
#  ('modern rock', 527),
#  ('hip hop', 501),
#  ('folk-pop', 500),
#  ('electro house', 485),
#  ('latin', 477),
#  ('indietronica', 476),
#  ('rap', 474),
#  ('pop rap', 454),
#  ('edm', 452),
#  ('indie rock', 423),
#  ('indie poptimism', 411),
#  ('tropical', 406),
#  ('vapor soul', 393),
#  ('indie r&b', 384),
#  ('funk', 381),
#  ('urban contemporary', 379),
#  ('latin rock', 378),
#  ('underground hip hop', 374),
#  ('christmas', 373),
#  ('neo-psychedelic', 370),
#  ('southern hip hop', 368),
#  ('folk rock', 368),
#  ('chamber pop', 368),
#  ('pop rock', 364),
#  ('indie pop', 363),
#  ('garage rock', 360),
#  ('folk', 359)]
